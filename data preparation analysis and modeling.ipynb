# %% [markdown]
# # Milestone 3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
covid = pd.read_csv('owid-covid-data.csv')
covid
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 194026      ZWE    Africa     Zimbabwe  2022-06-10     254031.0      252.0
# 194027      ZWE    Africa     Zimbabwe  2022-06-11     254031.0        0.0
# 194028      ZWE    Africa     Zimbabwe  2022-06-12     254098.0       67.0
# 194029      ZWE    Africa     Zimbabwe  2022-06-13     254155.0       57.0
# 194030      ZWE    Africa     Zimbabwe  2022-06-14     254155.0        0.0
#
# ...

# %%
covid = covid[covid['location'] == 'United States']
covid
# Out:
#        iso_code      continent       location       date  total_cases  \
# 182807      USA  North America  United States 2020-01-22          1.0
# 182808      USA  North America  United States 2020-01-23          1.0
# 182809      USA  North America  United States 2020-01-24          2.0
# 182810      USA  North America  United States 2020-01-25          2.0
# 182811      USA  North America  United States 2020-01-26          5.0
# ...         ...            ...            ...        ...          ...
# 183677      USA  North America  United States 2022-06-10   85468550.0
# 183678      USA  North America  United States 2022-06-11   85500710.0
# 183679      USA  North America  United States 2022-06-12   85515529.0
# 183680      USA  North America  United States 2022-06-13   85632808.0
# 183681      USA  North America  United States 2022-06-14   85758638.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %%
covid['date'] = pd.to_datetime(covid['date'])
covid
# Out:
#        iso_code      continent       location       date  total_cases  \
# 182807      USA  North America  United States 2020-01-22          1.0
# 182808      USA  North America  United States 2020-01-23          1.0
# 182809      USA  North America  United States 2020-01-24          2.0
# 182810      USA  North America  United States 2020-01-25          2.0
# 182811      USA  North America  United States 2020-01-26          5.0
# ...         ...            ...            ...        ...          ...
# 183677      USA  North America  United States 2022-06-10   85468550.0
# 183678      USA  North America  United States 2022-06-11   85500710.0
# 183679      USA  North America  United States 2022-06-12   85515529.0
# 183680      USA  North America  United States 2022-06-13   85632808.0
# 183681      USA  North America  United States 2022-06-14   85758638.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %%
covid.hist(bins = 15, edgecolor = "black", linewidth = 1.0, xlabelsize = 10, ylabelsize = 10, 
           grid = False, figsize = (30,30))
plt.show()

# %%
covid.describe(include='all')
# Out:
# C:\Users\jahed\AppData\Local\Temp\ipykernel_23276\2049601435.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   covid.describe(include='all')
#        iso_code      continent       location                 date  \
# count       875            875            875                  875
# unique        1              1              1                  875
# top         USA  North America  United States  2020-01-22 00:00:00
# freq        875            875            875                    1
# first       NaN            NaN            NaN  2020-01-22 00:00:00
# last        NaN            NaN            NaN  2022-06-14 00:00:00
# mean        NaN            NaN            NaN                  NaN
# std         NaN            NaN            NaN                  NaN
# ...

# %%
list(covid.columns)
# Out:
# ['iso_code',
#  'continent',
#  'location',
#  'date',
#  'total_cases',
#  'new_cases',
#  'new_cases_smoothed',
#  'total_deaths',
#  'new_deaths',
#  'new_deaths_smoothed',
#  'total_cases_per_million',
#  'new_cases_per_million',
#  'new_cases_smoothed_per_million',
#  'total_deaths_per_million',
#  'new_deaths_per_million',
#  'new_deaths_smoothed_per_million',
#  'reproduction_rate',
#  'icu_patients',
#  'icu_patients_per_million',
#  'hosp_patients',
#  'hosp_patients_per_million',
#  'weekly_icu_admissions',
#  'weekly_icu_admissions_per_million',
#  'weekly_hosp_admissions',
#  'weekly_hosp_admissions_per_million',
#  'total_tests',
#  'new_tests',
#  'total_tests_per_thousand',
#  'new_tests_per_thousand',
#  'new_tests_smoothed',
#  'new_tests_smoothed_per_thousand',
#  'positive_rate',
#  'tests_per_case',
#  'tests_units',
#  'total_vaccinations',
#  'people_vaccinated',
#  'people_fully_vaccinated',
#  'total_boosters',
#  'new_vaccinations',
# ...

# %%
covid_subset = covid[['iso_code',
 'continent',
 'location',
 'date',
 'total_cases',
 'new_cases','total_deaths',
 'new_deaths','new_cases_per_million', 
 'total_deaths_per_million',
 'new_deaths_per_million','total_vaccinations',
 'people_vaccinated',
 'people_fully_vaccinated',
 'total_boosters',
 'new_vaccinations', 
 'reproduction_rate',
 'icu_patients_per_million',
 'hosp_patients_per_million',
 'weekly_hosp_admissions_per_million','total_vaccinations_per_hundred',
 'people_vaccinated_per_hundred',
 'people_fully_vaccinated_per_hundred',
 'total_boosters_per_hundred',]]

# %%
covid_subset.head()
# Out:
#        iso_code      continent       location       date  total_cases  \
# 182807      USA  North America  United States 2020-01-22          1.0
# 182808      USA  North America  United States 2020-01-23          1.0
# 182809      USA  North America  United States 2020-01-24          2.0
# 182810      USA  North America  United States 2020-01-25          2.0
# 182811      USA  North America  United States 2020-01-26          5.0
#
#         new_cases  total_deaths  new_deaths  new_cases_per_million  \
# 182807        NaN           NaN         NaN                    NaN
# 182808        0.0           NaN         NaN                  0.000
# 182809        1.0           NaN         NaN                  0.003
# 182810        0.0           NaN         NaN                  0.000
# 182811        3.0           NaN         NaN                  0.009
#
#         total_deaths_per_million  ...  total_boosters  new_vaccinations  \
# ...

# %%
covid_subset.describe(include='all')
# Out:
# C:\Users\jahed\AppData\Local\Temp\ipykernel_23276\3997455110.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   covid_subset.describe(include='all')
#        iso_code      continent       location                 date  \
# count       875            875            875                  875
# unique        1              1              1                  875
# top         USA  North America  United States  2020-01-22 00:00:00
# freq        875            875            875                    1
# first       NaN            NaN            NaN  2020-01-22 00:00:00
# last        NaN            NaN            NaN  2022-06-14 00:00:00
# mean        NaN            NaN            NaN                  NaN
# std         NaN            NaN            NaN                  NaN
# ...

# %%
covid_subset.hist(bins = 15, edgecolor = "black", linewidth = 1.0, xlabelsize = 10, ylabelsize = 10, 
           grid = False, figsize = (30,30))
plt.show()

# %%
covid_subset.fillna(0)
# Out:
#        iso_code      continent       location       date  total_cases  \
# 182807      USA  North America  United States 2020-01-22          1.0
# 182808      USA  North America  United States 2020-01-23          1.0
# 182809      USA  North America  United States 2020-01-24          2.0
# 182810      USA  North America  United States 2020-01-25          2.0
# 182811      USA  North America  United States 2020-01-26          5.0
# ...         ...            ...            ...        ...          ...
# 183677      USA  North America  United States 2022-06-10   85468550.0
# 183678      USA  North America  United States 2022-06-11   85500710.0
# 183679      USA  North America  United States 2022-06-12   85515529.0
# 183680      USA  North America  United States 2022-06-13   85632808.0
# 183681      USA  North America  United States 2022-06-14   85758638.0
#
#         new_cases  total_deaths  new_deaths  new_cases_per_million  \
# ...

# %%
covid_subset.hist(bins = 15, edgecolor = "black", linewidth = 1.0, xlabelsize = 10, ylabelsize = 10, 
           grid = False, figsize = (30,30))
plt.show()

# %%
covid_subset['people_vaccinated_per_million'] = covid_subset['people_vaccinated_per_hundred']**10000
covid_subset.tail()
# Out:
# C:\Users\jahed\AppData\Local\Temp\ipykernel_35036\3237055051.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid_subset['people_vaccinated_per_million'] = covid_subset['people_vaccinated_per_hundred']**10000
#        iso_code      continent       location       date  total_cases  \
# 183677      USA  North America  United States 2022-06-10   85468550.0
# 183678      USA  North America  United States 2022-06-11   85500710.0
# 183679      USA  North America  United States 2022-06-12   85515529.0
# 183680      USA  North America  United States 2022-06-13   85632808.0
# 183681      USA  North America  United States 2022-06-14   85758638.0
#
#         new_cases  total_deaths  new_deaths  new_cases_per_million  \
# ...

# %%
plt.figure(figsize=(16,16))
plt.plot(covid_subset.date, covid_subset.weekly_hosp_admissions_per_million, label='hospital admissions')
plt.plot(covid_subset.date, covid_subset.new_cases_per_million, label='new cases')
plt.plot(covid_subset.date, covid_subset.new_deaths_per_million, label='new deaths')
plt.plot(covid_subset.date, covid_subset.icu_patients_per_million, label='icu patients')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.plot(covid_subset.date, covid_subset.new_deaths_per_million, label='new deaths')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.plot(covid_subset.date, covid_subset.new_vaccinations, label='new deaths')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.scatter('people_vaccinated_per_hundred', 'weekly_hosp_admissions_per_million', data=covid_subset)

# %% [raw]
# covid_subset.hist(bins = 15, edgecolor = "black", linewidth = 1.0, xlabelsize = 10, ylabelsize = 10,
#            grid = False, figsize = (30,30))
# plt.show()

# %%
corr = covid_subset.corr()

f, ax = plt.subplots(figsize=(11, 9))

mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True

cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, cmap=cmap, mask=mask, center=0,
           square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
covid.corr()
# Out:
#                                          total_cases  new_cases  \
# total_cases                                 1.000000   0.286805
# new_cases                                   0.286805   1.000000
# new_cases_smoothed                          0.328451   0.904930
# total_deaths                                0.976171   0.259630
# new_deaths                                 -0.015942   0.473570
# ...                                              ...        ...
# human_development_index                          NaN        NaN
# excess_mortality_cumulative_absolute        0.974032   0.271367
# excess_mortality_cumulative                 0.684783   0.316108
# excess_mortality                            0.043530   0.522876
# excess_mortality_cumulative_per_million     0.974032   0.271367
#
#                                          new_cases_smoothed  total_deaths  \
# total_cases                                        0.328451      0.976171
# ...

# %% [markdown]
# # Milestone 4

# %%
covid_subset_model = covid[['total_cases',
 'new_cases','total_deaths',
 'new_deaths','new_cases_per_million', 
 'total_deaths_per_million',
 'new_deaths_per_million','total_vaccinations',
 'people_vaccinated',
 'people_fully_vaccinated',
 'total_boosters',
 'new_vaccinations', 
 'reproduction_rate',
 'icu_patients_per_million',
 'hosp_patients_per_million',
 'weekly_hosp_admissions_per_million','total_vaccinations_per_hundred',
 'people_vaccinated_per_hundred',
 'people_fully_vaccinated_per_hundred',
 'total_boosters_per_hundred',]]
covid_subset_model = covid_subset_model.fillna(0)
covid_subset_model
# Out:
#         total_cases  new_cases  total_deaths  new_deaths  \
# 182807          1.0        0.0           0.0         0.0
# 182808          1.0        0.0           0.0         0.0
# 182809          2.0        1.0           0.0         0.0
# 182810          2.0        0.0           0.0         0.0
# 182811          5.0        3.0           0.0         0.0
# ...             ...        ...           ...         ...
# 183677   85468550.0   106156.0     1011164.0       359.0
# 183678   85500710.0    32160.0     1011260.0        96.0
# 183679   85515529.0    14819.0     1011275.0        15.0
# 183680   85632808.0   117279.0     1011543.0       268.0
# 183681   85758638.0   125830.0     1011925.0       382.0
#
#         new_cases_per_million  total_deaths_per_million  \
# 182807                  0.000                     0.000
# 182808                  0.000                     0.000
# 182809                  0.003                     0.000
# ...

# %%
covid_subset_model['change'] = np.where(covid_subset_model.weekly_hosp_admissions_per_million.diff() > 0, 1, 0)
covid_subset_model
# Out:
#         total_cases  new_cases  total_deaths  new_deaths  \
# 182807          1.0        0.0           0.0         0.0
# 182808          1.0        0.0           0.0         0.0
# 182809          2.0        1.0           0.0         0.0
# 182810          2.0        0.0           0.0         0.0
# 182811          5.0        3.0           0.0         0.0
# ...             ...        ...           ...         ...
# 183677   85468550.0   106156.0     1011164.0       359.0
# 183678   85500710.0    32160.0     1011260.0        96.0
# 183679   85515529.0    14819.0     1011275.0        15.0
# 183680   85632808.0   117279.0     1011543.0       268.0
# 183681   85758638.0   125830.0     1011925.0       382.0
#
#         new_cases_per_million  total_deaths_per_million  \
# 182807                  0.000                     0.000
# 182808                  0.000                     0.000
# 182809                  0.003                     0.000
# ...

# %%
# Import train_test_split function
from sklearn.model_selection import train_test_split

X = covid_subset_model.drop(columns=['change', 'weekly_hosp_admissions_per_million'])  # Features
y = covid_subset_model.change  # Labels

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3) # 70% training and 30% test

# %%
# Import Random Forest Model
from sklearn.ensemble import RandomForestClassifier

# Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)

# Train the model using the training sets
clf.fit(X_train,y_train)

y_pred = clf.predict(X_test)

# %%
# Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9011406844106464
